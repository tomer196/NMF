# %%
import os
import pandas as pd

# %%
data_path = "./data/"

# %%
An = pd.read_csv("./data/An.csv")
H_true = pd.read_csv("./data/H_true.csv")
W_true = pd.read_csv("./data/W_true.csv")

An_raman = pd.read_csv("./data/An_raman.csv")
H_true_raman = pd.read_csv("./data/H_true_raman.csv")
W_true_raman = pd.read_csv("./data/W_true_raman.csv")

# %%
An.shape, H_true.shape, W_true.shape
# Out:
# ((150, 101), (5, 101), (150, 6))

# %%
An_raman.shape, H_true_raman.shape, W_true_raman.shape
# Out:
# ((650, 51), (5, 51), (650, 6))

# %%
import matplotlib.pyplot as plt


plt.figure()
plt.plot(An_raman.values[:, 50])
plt.xlabel("Peak location")
# Out:
# Text(0.5, 0, 'Peak location')

# %%
plt.figure()
plt.plot(W_true.values[:, 1:20])
